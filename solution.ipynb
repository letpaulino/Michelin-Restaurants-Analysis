# %%
from Dataset import Dataset
from Util import load_restaurants
import analysis as a

restaurants = load_restaurants(Dataset.MICHELIN.value)

a.plot_top_regions(restaurants)
a.plot_nordic_histogram(restaurants)
a.plot_swedish_stars(restaurants)
a.plot_swedish_cuisine(restaurants)
a.plot_global_cuisine(restaurants)
a.plot_price_category(restaurants)


m = a.plot_map(restaurants)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edf7c9da400139b854556ce46c833cf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edf7c9da400139b854556ce46c833cf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edf7c9da400139b854556ce46c833cf6 = L.map(
#                 &quot;map_edf7c9da400139b854556ce46c833cf6&quot;,
#                 {
#                     center: [59.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc8df403cd48dcea01884d38792a1379 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc8df403cd48dcea01884d38792a1379.addTo(map_edf7c9da400139b854556ce46c833cf6);
#
#
#             var circle_marker_a7be8fa180effe8e8fbbdbb7877f3240 = L.circleMarker(
#                 [47.34858, 10.17114],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_edf7c9da400139b854556ce46c833cf6);
#
#
#         var popup_251b43fd08237c2d67ff19656498f5a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06c7e6fbe1cbf9d71ff9fc76f3b44eb1 = $(`&lt;div id=&quot;html_06c7e6fbe1cbf9d71ff9fc76f3b44eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kilian Stuba (1⭐)&lt;/div&gt;`)[0];
#                 popup_251b43fd08237c2d67ff19656498f5a9.setContent(html_06c7e6fbe1cbf9d71ff9fc76f3b44eb1);
#
#
#
#         circle_marker_a7be8fa180effe8e8fbbdbb7877f3240.bindPopup(popup_251b43fd08237c2d67ff19656498f5a9)
#         ;
#
#
#
#
#             var circle_marker_069d6720364e6c68182eedef29464f83 = L.circleMarker(
#                 [47.83787, 13.07917],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_edf7c9da400139b854556ce46c833cf6);
#
#
#         var popup_ae9ae1f0bcc5459743e23793e09e491c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71489ddbea26a6c3a16a0cca9f408abb = $(`&lt;div id=&quot;html_71489ddbea26a6c3a16a0cca9f408abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pfefferschiff (1⭐)&lt;/div&gt;`)[0];
#                 popup_ae9ae1f0bcc5459743e23793e09e491c.setContent(html_71489ddbea26a6c3a16a0cca9f408abb);
#
#
#
#         circle_marker_069d6720364e6c68182eedef29464f83.bindPopup(popup_ae9ae1f0bcc5459743e23793e09e491c)
#         ;
#
#
#
#
#             var circle_marker_25c8830e752bfec47bc6d261d8c84a06 = L.circleMarker(
#                 [47.80685, 13.03409],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_edf7c9da400139b854556ce46c833cf6);
#
#
#         var popup_a7a81f5e45c33698840868395de6bd83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30a22a1151762e4aee370f7ed7cf7b88 = $(`&lt;div id=&quot;html_30a22a1151762e4aee370f7ed7cf7b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Esszimmer (1⭐)&lt;/div&gt;`)[0];
#                 popup_a7a81f5e45c33698840868395de6bd83.setContent(html_30a22a1151762e4aee370f7ed7cf7b88);
#
#
#
#         circle_marker_25c8830e752bfec47bc6d261d8c84a06.bindPopup(popup_a7a81f5e45c33698840868395de6bd83)
#         ;
#
#
#
#
#             var circle_marker_15e205053f8c59b86b9b7ac2a0ca49c3 = L.circleMarker(
#                 [47.80001, 13.04006],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &
